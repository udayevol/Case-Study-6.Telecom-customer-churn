# %% [markdown]
# **IMPORTING NECESSARY LIBRARIES**

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the dataset and reading the data which is in csv form**

# %%
# Load the dataset
churn = pd.read_csv("/kaggle/input/maven-churn-dataset/telecom_customer_churn.csv")
churn.head(5)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %% [markdown]
# **Exploring the dataset shapes and datatypes.**

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %% [markdown]
# **We are loading the data to see the basic statistics.**

# %%
churn.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
churn.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %% [markdown]
# **Question1: How many customers joined the company? How many customers joined?**

# %%
# Customers who joined and stayed
joined = churn[churn['Customer Status'] == 'Joined']
num_joined = joined.shape[0]
num_joined

# Plot the number of customers who joined
plt.figure(figsize=(6, 4))
plt.bar(['Joined'], num_joined, color='blue')
plt.title('Number of Customers Who Joined')
plt.xlabel('Customer Status')
plt.ylabel('Number of Customers')

plt.show()

# %% [markdown]
# **Number of Customers who Joined: 454**

# %% [markdown]
# **Gender Distribution of Joined Customer**

# %%
joined = churn[churn['Customer Status'] == 'Joined']
gender_joined_num = joined['Gender'].value_counts()
gender_distribution = joined['Gender'].value_counts(normalize=True) * 100
gender_joined_num, gender_distribution


# Plotting the count of joined customers by gender
plt.figure(figsize=(8, 6))
gender_joined_num.plot(kind='bar', color=['blue', 'green'], alpha=0.7)
plt.title('Gender Distribution of Joined Customers')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()

# Plotting the percentage distribution of joined customers by gender
plt.figure(figsize=(8, 6))
gender_distribution.plot(kind='bar', color=['blue', 'green'], alpha=0.7)
plt.title('Percentage of Joined Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage of Customers')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()

# %% [markdown]
# **Age Group Distribution of Joined Customers**

# %%
# Define bins and labels
bins = [18, 30, 45, 60, churn['Age'].max() + 1]  # Added max+1 to include the upper limit
labels = ['18-30', '31-45', '46-60', '61+']

# Create Age Group column
churn['Age Group'] = pd.cut(churn['Age'], bins=bins, labels=labels, right=False)

# Map Age Group labels to descriptive names
age_group_names = ['Young Adults', 'Adults', 'Middle-Aged Adults', 'Seniors']
age_group_map = dict(zip(labels, age_group_names))
churn['Age Group Name'] = churn['Age Group'].map(age_group_map)

# Filter for customers who joined
joined = churn[churn['Customer Status'] == 'Joined']

# Age group distribution and counts
age_group_distribution = joined['Age Group Name'].value_counts(normalize=True) * 100
age_group_distribution_num = joined['Age Group Name'].value_counts()

age_group_distribution, age_group_distribution_num

#Plot
plt.figure(figsize=(12, 8))
age_group_distribution.plot(kind='bar', color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Age Group')
plt.ylabel('Percentage of Joined Customers')
plt.title('Age Group Distribution of Joined Customers')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
age_group_distribution_num.plot(kind='bar', color='skyblue')
plt.xlabel('Age Group')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Number of Joined Customers')
plt.title('Age Group Distribution of Joined Customers')
plt.tight_layout()
plt.show()

# %% [markdown]
# **City Distribution**

# %%
# City distribution
city_distribution = joined['City'].value_counts()

city_distribution
# Out:
# City
# Los Angeles       18
# San Francisco      7
# San Diego          7
# Sacramento         6
# Glendale           6
#                   ..
# Lookout            1
# Amboy              1
# Castroville        1
# Woodland Hills     1
# Elk                1
# Name: count, Length: 329, dtype: int64

# %% [markdown]
# **Internet Service Distribution**

# %%
# Internet service distribution
internet_service_distribution = joined['Internet Service'].value_counts(normalize=True) * 100
internet_service_distribution_num = joined['Internet Service'].value_counts()

internet_service_distribution, internet_service_distribution_num

# Plotting the distribution as a pie chart
plt.figure(figsize=(8, 6))
plt.pie(internet_service_distribution, labels=internet_service_distribution.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Internet Services')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# Optionally, you can also plot the count of each internet service using a bar chart
plt.figure(figsize=(8, 6))
plt.bar(internet_service_distribution_num.index, internet_service_distribution_num.values, color='skyblue')
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.title('Count of Each Internet Service')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Average Revenue**

# %%
# Average revenue and 
average_revenue = joined['Total Revenue'].mean()
average_revenue
# Out:
# 119.55892070484582

# %% [markdown]
# **Average GB Consumed**

# %%
#GB consumed
average_gb_consumed = joined['Avg Monthly GB Download'].mean()
average_gb_consumed
# Out:
# 25.496323529411764

# %% [markdown]
# **Unlimited Data Distribution**

# %%
# Unlimited data
unlimited_data_distribution = joined['Unlimited Data'].value_counts(normalize=True) * 100
unlimited_data_num = joined['Unlimited Data'].value_counts()

unlimited_data_distribution, unlimited_data_num

# Plot
plt.figure(figsize=(8, 6))
unlimited_data_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Unlimited Data')
plt.xlabel('Unlimited Data')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.show()

# Plot
plt.figure(figsize=(8, 6))
unlimited_data_num.plot(kind='bar', color='skyblue')
plt.title('Counts of Unlimited Data')
plt.xlabel('Unlimited Data')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **All Streaming Services numbers**

# %%
streaming_tv_num = joined['Streaming TV'].value_counts()
streaming_movies_num = joined['Streaming Movies'].value_counts()
streaming_music_num = joined['Streaming Music'].value_counts()
streaming_tv_num, streaming_movies_num, streaming_music_num

#Plotting
plt.figure(figsize=(15, 5))

# Plot for Streaming TV
plt.subplot(1, 3, 1)
streaming_tv_num.plot(kind='bar', color='skyblue')
plt.title('Streaming TV')
plt.xticks(rotation=0, ha='right')

# Plot for Streaming Movies
plt.subplot(1, 3, 2)
streaming_movies_num.plot(kind='bar', color='orange')
plt.title('Streaming Movies')
plt.xticks(rotation=0, ha='right')

# Plot for Streaming Music
plt.subplot(1, 3, 3)
streaming_music_num.plot(kind='bar', color='green')
plt.title('Streaming Music')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **454 customers joined the company. Further analysis includes gender distribution, age group distribution, city distribution, internet service distribution, average revenue, average GB consumed, unlimited data distribution, and numbers for all streaming services.**

# %% [markdown]
# **Question 2: What is the customer profile for a customer that churned, joined, and stayed?**

# %% [markdown]
# **Gender Distribution for customer profile**

# %%
# Customer profile of Joined stayed and churned
joined = churn[churn['Customer Status'] == 'Joined']
stayed = churn[churn['Customer Status'] == 'Stayed']
churned = churn[churn['Customer Status'] == 'Churned']

# Gender distribution for different customer statuses
gender_churned = churned['Gender'].value_counts(normalize=True) * 100
gender_stayed = stayed['Gender'].value_counts(normalize=True) * 100
gender_joined = joined['Gender'].value_counts(normalize=True) * 100

gender_churned_num = churned['Gender'].value_counts()
gender_stayed_num = stayed['Gender'].value_counts()
gender_joined_num = joined['Gender'].value_counts()

gender_churned, gender_stayed, gender_joined, gender_churned_num, gender_stayed_num, gender_joined_num

#Plotting
plt.figure(figsize=(15, 5))

# Plot for gender churned
plt.subplot(1, 3, 1)
gender_churned.plot(kind='bar', color='skyblue')
plt.title('Percentage of Gender Churned')
plt.xticks(rotation=0, ha='right')

# Plot for gender stayed
plt.subplot(1, 3, 2)
gender_stayed.plot(kind='bar', color='orange')
plt.title('Percentage of Gender Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for gender joined
plt.subplot(1, 3, 3)
gender_joined.plot(kind='bar', color='green')
plt.title('Percentage of Gender Joined')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

#Plotting
plt.figure(figsize=(15, 5))

# Plot for gender churned
plt.subplot(1, 3, 1)
gender_churned_num.plot(kind='bar', color='skyblue')
plt.title('Count of Gender Churned')
plt.xticks(rotation=0, ha='right')

# Plot for gender stayed
plt.subplot(1, 3, 2)
gender_stayed_num.plot(kind='bar', color='orange')
plt.title('Count of Gender Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for gender joined
plt.subplot(1, 3, 3)
gender_joined_num.plot(kind='bar', color='green')
plt.title('Count of Gender Joined')
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Age group Distribution for customer profile**

# %%
# Calculate age group distributions for different customer statuses
age_group_churned = churned['Age Group Name'].value_counts(normalize=True) * 100
age_group_stayed = stayed['Age Group Name'].value_counts(normalize=True) * 100
age_group_joined = joined['Age Group Name'].value_counts(normalize=True) * 100

# Calculate number distribution of age groups for different customer statuses
age_group_churned_num = churned['Age Group Name'].value_counts()
age_group_stayed_num = stayed['Age Group Name'].value_counts()
age_group_joined_num = joined['Age Group Name'].value_counts()

# Display results
age_group_churned, age_group_churned_num, age_group_stayed, age_group_stayed_num, age_group_joined, age_group_joined_num

#Plotting
plt.figure(figsize=(15, 5))

# Plot for age group churn
plt.subplot(1, 3, 1)
age_group_churned.plot(kind='bar', color='skyblue')
plt.title('Percentage of Age Group Churned')
plt.xticks(rotation=45, ha='right')

# Plot for age group stayed
plt.subplot(1, 3, 2)
age_group_stayed.plot(kind='bar', color='orange')
plt.title('Percentage of Age Group Stayed')
plt.xticks(rotation=45, ha='right')

# Plot for age group churn joined
plt.subplot(1, 3, 3)
age_group_joined.plot(kind='bar', color='green')
plt.title('Percentage of Age Group Joined')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

#Plotting
plt.figure(figsize=(15, 5))

# Plot for age group churn
plt.subplot(1, 3, 1)
age_group_churned_num.plot(kind='bar', color='skyblue')
plt.title('Count of Age Group Churned')
plt.xticks(rotation=45, ha='right')

# Plot for age group stayed
plt.subplot(1, 3, 2)
age_group_stayed_num.plot(kind='bar', color='orange')
plt.title('Count of Age Group Stayed')
plt.xticks(rotation=45, ha='right')

# Plot for age group joined
plt.subplot(1, 3, 3)
age_group_joined_num.plot(kind='bar', color='green')
plt.title('Count of Age Group Joined')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Internet Service distribution for customer profile**

# %%
Internet_service_churn = churned['Internet Service'].value_counts(normalize=True)*100
Internet_service_joined = joined['Internet Service'].value_counts(normalize=True)*100
Internet_service_stayed = stayed['Internet Service'].value_counts(normalize=True)*100

churned_counts = churned['Internet Service'].value_counts()
joined_counts = joined['Internet Service'].value_counts()
stayed_counts = stayed['Internet Service'].value_counts()


#Plotting
plt.figure(figsize=(15, 5))

# Plot for interner services churn
plt.subplot(1, 3, 1)
Internet_service_churn.plot(kind='bar', color='skyblue')
plt.title('Percentage of Internet Services Churned')
plt.xticks(rotation=0, ha='right')

# Plot for interner services joined
plt.subplot(1, 3, 2)
Internet_service_joined.plot(kind='bar', color='orange')
plt.title('Percentage of Internet Services Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for interner services
plt.subplot(1, 3, 3)
Internet_service_stayed.plot(kind='bar', color='green')
plt.title('Percentage of Internet Services Joined')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

#Plotting
plt.figure(figsize=(15, 5))

# Plot for interner services
plt.subplot(1, 3, 1)
churned_counts.plot(kind='bar', color='skyblue')
plt.title('Count of Age Group Churned')
plt.xticks(rotation=0, ha='right')

# Plot for interner services
plt.subplot(1, 3, 2)
joined_counts.plot(kind='bar', color='orange')
plt.title('Count of Age Group Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for interner services
plt.subplot(1, 3, 3)
stayed_counts.plot(kind='bar', color='green')
plt.title('Count of Age Group Joined')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Average Revenue for customer profile**

# %%
# Average revenue 
average_revenue_churn = churned['Total Revenue'].mean()
average_revenue_joined = joined['Total Revenue'].mean()
average_revenue_stayed = stayed['Total Revenue'].mean()

categories = ['Churned', 'Joined', 'Stayed']
average_revenues = [average_revenue_churn, average_revenue_joined, average_revenue_stayed]

# Plot
plt.figure(figsize=(8, 6))
plt.bar(categories, average_revenues, color=['red', 'green', 'blue'])
plt.title('Average Revenue by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Average Revenue')
plt.show()

# %% [markdown]
# **Average GB consumer for customer profile**

# %%
# Average GB consumed
average_GB_churn = churned['Avg Monthly GB Download'].mean()
average_GB_joined = joined['Avg Monthly GB Download'].mean()
average_GB_stayed = stayed['Avg Monthly GB Download'].mean()



categories = ['Churned', 'Joined', 'Stayed']
average_GB_consumed = [average_GB_churn,average_GB_joined,average_GB_stayed]

# Plot
plt.figure(figsize=(8, 6))
plt.bar(categories, average_GB_consumed, color=['red', 'green', 'blue'])
plt.title('Average GB Consumed by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Average Revenue')
plt.show()

# %% [markdown]
# **Unlimited Data for customer profile.**

# %%
# Unlimited data
unlimited_data_distribution_joined = joined['Unlimited Data'].value_counts(normalize=True) * 100
unlimited_data_distribution_stayed = stayed['Unlimited Data'].value_counts(normalize=True) * 100
unlimited_data_distribution_churned = churned['Unlimited Data'].value_counts(normalize=True) * 100


unlimited_data_num_joined = joined['Unlimited Data'].value_counts()
unlimited_data_num_stayed = stayed['Unlimited Data'].value_counts()
unlimited_data_num_churned = churned['Unlimited Data'].value_counts()

#Plotting
plt.figure(figsize=(15, 5))

# Plot for unlimited data
plt.subplot(1, 3, 1)
unlimited_data_distribution_churned.plot(kind='bar', color='skyblue')
plt.title('Percentage of Unlimited Data Churned')
plt.xticks(rotation=0, ha='right')

# Plot for unlimited data
plt.subplot(1, 3, 2)
unlimited_data_distribution_stayed.plot(kind='bar', color='orange')
plt.title('Percentage of Unlimited Data Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for unlimited data
plt.subplot(1, 3, 3)
unlimited_data_distribution_joined.plot(kind='bar', color='green')
plt.title('Percentage of Unlimited Data Joined')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

#Plotting
plt.figure(figsize=(15, 5))

# Plot for unlimited data
plt.subplot(1, 3, 1)
unlimited_data_num_joined.plot(kind='bar', color='skyblue')
plt.title('Count of Unlimited Data Joined')
plt.xticks(rotation=0, ha='right')

# Plot for unlimited data
plt.subplot(1, 3, 2)
unlimited_data_num_stayed.plot(kind='bar', color='orange')
plt.title('Count of Unlimited Data Stayed')
plt.xticks(rotation=0, ha='right')

# Plot for unlimited data
plt.subplot(1, 3, 3)
unlimited_data_num_churned.plot(kind='bar', color='green')
plt.title('Count of Unlimited Data Churned')
plt.xticks(rotation=0, ha='right')

plt.tight_layout()
plt.show()

# %%
streaming_tv_joined_num = joined['Streaming TV'].value_counts()
streaming_tv_churned_num = churned['Streaming TV'].value_counts()
streaming_tv_stayed_num = stayed['Streaming TV'].value_counts()

# Combine data into a DataFrame
data = {
    'Joined': streaming_tv_joined_num,
    'Churned': streaming_tv_churned_num,
    'Stayed': streaming_tv_stayed_num
}

tv = pd.DataFrame(data)

# Plot
tv.plot(kind='bar', figsize=(10, 6))
plt.title('Streaming TV Usage by Customer Status')
plt.xlabel('Streaming TV')
plt.ylabel('Number of Customers')
plt.legend(title='Customer Status')
plt.xticks(rotation=0)
plt.show()

# %%
streaming_movies_joined_num = joined['Streaming Movies'].value_counts()
streaming_movies_churned_num = churned['Streaming Movies'].value_counts()
streaming_movies_stayed_num = stayed['Streaming Movies'].value_counts()

data ={ 
      'Joined': streaming_movies_joined_num,
      'Churned': streaming_movies_churned_num,
      'Stayed' : streaming_movies_stayed_num,
      }

movies = pd.DataFrame(data)

# Plot
movies.plot(kind='bar', figsize=(10, 6))
plt.title('Streaming Movies Usage by Customer Status')
plt.xlabel('Streaming Movies')
plt.ylabel('Number of Customers')
plt.legend(title='Customer Status')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **All streming services number for customer profile**

# %%
# All Streaming Services Distribution
streaming_columns = ['Streaming TV', 'Streaming Music', 'Streaming Movies']
streaming_services = churn[streaming_columns].sum(axis=1)
streaming_services

plt.figure(figsize=(10, 5))
sns.countplot(x=streaming_services, hue='Customer Status', data=churn)

plt.title('Count of All Streaming Services')
plt.xlabel('Number of Streaming Services')
plt.ylabel('Number of Customers')
plt.legend(title='Customer Status')

plt.show()

# %% [markdown]
# **Analysis includes gender distribution, age group distribution, internet service distribution, average revenue, average GB consumed, unlimited data distribution, and numbers for all streaming services for customers who churned, joined, and stayed.**

# %% [markdown]
# **Question 3: What seems to be the key drivers of customer churn?**

# %%
# Key drivers of customer churn
churn_reasons = churned['Churn Reason'].value_counts()

churn_reasons
 #Plot
plt.figure(figsize=(12, 8))
churn_reasons.plot(kind='bar', color='skyblue')
plt.title('Key Drivers of Customer Churn')
plt.xlabel('Churn Reason')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 4: Is the company losing high-value customers? If so, how can they retain them?**

# %%
# Define high-value threshold (e.g., top 25% in terms of total revenue)
high_value_threshold = churn['Total Revenue'].quantile(0.75)

# Identify high-value customers
high_value_customers = churn[churn['Total Revenue'] > high_value_threshold]

# Calculate churn rate among high-value customers
high_value_churned = high_value_customers[high_value_customers['Customer Status'] == 'Churned']
high_value_churned_rate = len(high_value_churned) / len(high_value_customers) * 100

print(f"High-Value Customer Churn Rate: {high_value_churned_rate:.2f}%")

# Analyze churn reasons for high-value customers
high_value_churn_reasons = high_value_churned['Churn Reason'].value_counts()


plt.figure(figsize=(12, 8))
high_value_churn_reasons.plot(kind='bar', color='orange')
plt.title('Churn Reasons for High-Value Customers')
plt.xlabel('Churn Reason')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Retention Strategies
# Example: If "Competitor Offer" is a major churn reason, consider strategies like loyalty programs, better offers, etc.
# Out:
# High-Value Customer Churn Rate: 14.82%

# %% [markdown]
# **Bar plot compares high-value customers churn rate with the overall churn rate. **

# %% [markdown]
# **Question 5: Out of the 3 customer statuses, stayed, churned, and joined, which has the highest %?**

# %%
#Calculate the percentage distribution of each customer status
customer_status_distribution = churn['Customer Status'].value_counts(normalize=True) * 100

customer_status_distribution

#Plot
plt.figure(figsize=(12, 8))
customer_status_distribution.plot(kind='bar', color='skyblue')
plt.title('Customer Status Distribution: Stayed vs. Churned vs. Joined')
plt.xlabel('Customer Status')
plt.ylabel('Percentage')
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Bar plot shows customer status distribution where stayed customers have the highest percentage (67.02%), followed by churned (26.54%), and joined (6.45%).**

# %% [markdown]
# **Question 6: What payment method was preferred by churned users?**

# %%
# Filter for churned users
churned_users = churn[churn['Customer Status'] == 'Churned']

# Calculate the preferred payment method among churned users
payment_method_distribution_num = churned_users['Payment Method'].value_counts()
payment_method_distribution_num

#Plot
plt.figure(figsize=(12, 8))
payment_method_distribution_num.plot(kind='bar', color='green')
plt.title('Payment Method Preferred By Churn Users')
plt.xlabel('Payment Method')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Bar plot shows payment method preferred by churned users, bank withdrawal was most preferred payment method, followed by credit card and mailed check.**

# %% [markdown]
# **Question 7: What are the top 12 cities that churned?**

# %%
# Top 12 cities with highest churn rate
top_cities_churned = churned['City'].value_counts().head(12)

top_cities_churned

#Plot
plt.figure(figsize=(12, 8))
top_cities_churned.plot(kind='bar', color='skyblue')
plt.title('Top 12 Cities with Highest Churn')
plt.xlabel('Cities')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Bar plot shows top 12 highest cities churned where San diego has highest churn count compared to other cities**

# %% [markdown]
# **Question 8: What churn offers were preferable by the customers?**

# %%
# Filter for churned customers
churned_customers = churn[churn['Customer Status'] == 'Churned']

# Further filter for customers who received offers
churned_customers_with_offers = churned_customers.dropna(subset=['Offer'])

# Calculate the preferred offers among churned customers
churned_offer_distribution_num = churned_customers_with_offers['Offer'].value_counts()


#Plot
plt.figure(figsize=(12, 8))
churned_offer_distribution_num.plot(kind='bar', color='skyblue')
plt.title('Preferred Churn Offers by Customers')
plt.xlabel('Offers')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Among churned customers who received offers, Offer E was the most preferable, followed by Offer D, Offer B, Offer C, and Offer A.**
